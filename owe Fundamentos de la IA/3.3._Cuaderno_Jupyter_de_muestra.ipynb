# %% [markdown]
# # Cuaderno Jupyter de Muestra
#
# ### ¿Qué es un cuaderno de Jupyter?
#
# Los cuadernos de Jupyter son una herramienta que permite intercalar celdas de textos y celdas de código Python ejecutable.
#
# Es una herramienta ideal para empezar a programar porque nos permite añadir notas o apuntes así como ir probando el código de manera interactiva a medida que lo vamos elaborando. Además es una herramienta ideal para la docencia por su facilidad de uso e interacción y también por la posibilidad de ser modificados de manera sencilla por los alumnos.
#
# Las dos prácticas que veremos a lo largo de este curso se presentarán en cuadernos de Jupyter que podrán ser modificados y ejecutados por los alumnos.
#
# ### ¿Qué funcionalidades tiene un cuaderno de Jupyter?
#
# En primer lugar y como mencionamos observamos que es posible intercalar celdas de texto y celdas de código ejecutable:

# %%
print("¡Bienvenido/a a esta clase!")
# Out:
# ¡Bienvenido/a a esta clase!

# %% [markdown]
# El entorno de ejecución de este código se conserva a lo largo de todo el cuaderno. Esto quiere decir que si definimos una variable en una celda:

# %%
saludo = "Hola"

# %% [markdown]
# Esta variable seguirá existiendo en las celdas posteriores y podrá ser utilizada:

# %%
print(saludo)
# Out:
# Hola

# %% [markdown]
# __Nota.__ Es importante tener en cuenta que la ejecución del código del cuaderno es a demanda del usuario, es decir, que si ejecutamos una celda esto no quiere decir que las celdas anteriores hayan sido ejecutadas, lo que puede llevar a errores. Veámoslo con un ejemplo:

# %%
despedida = "Hasta la próxima"

# %%
print(despedida)
# Out:
# Hasta la próxima

# %% [markdown]
# Los cuadernos de Jupyter poseen muchas de las funcionalidades de los grandes procesadores de textos, por ejemplo, podemos usar letra **negrita**, *cursiva*, o <u>subrayada</u>.
#
# En general podemos introducir muchos tipos de órdenes usando código HTML y CSS, como, por ejemplo, el subrayado del párrafo anterior.
#
# Además es posible añadir [enlaces](https://openwebinars.net/) para acceso a información detallada o documentación.
#
# Los cuadernos de Jupyter también nos permiten insertar imágenes como por ejemplo esta foto de Alan Turing:
#
# ![ALAN TURING.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# O incluso vídeos de Youtube:

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/xN-JCdM4or0?si=Jg6k1-7UoSdFapIi" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/xN-JCdM4or0?si=Jg6k1-7UoSdFapIi" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Además a la hora de programar añaden funcionalidades propias llamados comandos magic que nos ayudan a programar. Por ejemplo, podemos usar comandos típicos de Lynux:

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# Mediante el siguiente comando puedes ver una lista de todos los comandos "magic" disponibles:

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# Uno de los comandos "mágicos" más interesantes es el de HTML que nos permite insertar códigos completos de HTML y visualizarlos directamente en el cuaderno lo cual potencia aún más la versatilidad.

# %%
# %%HTML
#
# <font color="yellow">Este texto es rojo</font>
# Out:
# <font color="yellow">Este texto es rojo</font>

# %% [markdown]
# Por último y como hemos visto en las clases previas una de las funcionalidades más interesantes de Python a la hora de programar es la existencia de bibliotecas de código para realizar funcionalidades específicas.
#
# Veámos un ejemplo de cómo importar y utilizar bibliotecas de Python para realizar una pequeña gráfica:
#
# Para importar las bibliotecas simplemente:

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# %% [markdown]
# Una vez importados los módulos podemos usar las funciones contenidas en los mismos.
#
# Empezamos generando unos datos de muestra:

# %%
muestra = 10000
media = [0, 0]
covarianza = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(media, covarianza, muestra).T

# %% [markdown]
# Tras esto generamos la visualización que encadena distintos gráficos:

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <Axes: >

# %% [markdown]
# Con cuatro líneas de código hemos sido capaces de visualizar los datos de una manera bastante compleja sin necesidad de construir funciones complicadas o perder el tiempo en generar todo el marco de la imagen desde cero. Esta es la potencia del uso de módulo que veremos más en profundidad en las próximas clases prácticas.
#
# Google Colab viene con una gran variedad de bibliotecas instaladas pero si necesitáramos instalar alguna biblioteca (o si estás trabajando desde tu propio entorno de Python) es tan sencillo como ejecutar un comando de la forma:
#
# !pip install nombre del paquete
#
# Veámos un ejemplo:

# %%
# !pip install pandas

# %% [markdown]
# Esto es todo por ahora.
#
# No dudes en clonar este cuaderno, explorarlo y modificarlo. Prueba a incrustar tus propios vídeos o código HTML (generado por ti o por ChatGPT). A modificar textos y formatearlos o a intentar instalar e importar otros módulos. A medida que vayas trabajando con esta herramienta irás viendo lo fácil e intuitivo de la misma.
#
# ¡Muchas gracias!
